# %% [markdown]
# ### Crime visualizations using Open Data DC

# %%
##import packages
import pandas as pd
import numpy as np
import os
from plotnine import *
import scipy.stats as stats 
import warnings
warnings.filterwarnings("ignore")
import re

# %% [markdown]
# #### 2024 Crime Data

# %%
##import data and show the first few rows
crime_2024 = pd.read_csv("../../data/open_data_dc/Crime_Incidents_in_2024_with_neighborhood.csv", encoding='utf-8')
crime_2024.head()
# Out:
#    Unnamed: 0          X            Y       CCN              REPORT_DAT  \
# 0           0  400040.61  129046.4721  18060158  2024/07/30 04:00:00+00
# 1           1  399950.92  138510.6000  23168245  2024/05/09 04:00:00+00
# 2           2  404689.01  135000.8400  24000194  2024/01/01 11:50:13+00
# 3           3  401508.58  137047.0200  24000222  2024/01/01 13:56:32+00
# 4           4  393930.75  143053.2700  24000236  2024/01/01 14:59:02+00
#
#       SHIFT  METHOD      OFFENSE                                       BLOCK  \
# 0  MIDNIGHT     GUN     HOMICIDE     400 - 599 BLOCK OF CHESAPEAKE STREET SE
# 1  MIDNIGHT  OTHERS     HOMICIDE          1800 - 1829 BLOCK OF 4TH STREET NE
# 2  MIDNIGHT  OTHERS  THEFT/OTHER            4000 - 4099 BLOCK OF E STREET SE
# 3       DAY  OTHERS  THEFT/OTHER      812 - 899 BLOCK OF BLADENSBURG ROAD NE
# 4       DAY  OTHERS  THEFT/OTHER  5000 - 5099 BLOCK OF CONNECTICUT AVENUE NW
#
#           XBLOCK  ...  VOTING_PRECINCT   LATITUDE  LONGITUDE  BID  \
# ...

# %%
##list of neighborhoods of interest
neighborhoods = [
    'Adams Morgan','Anacostia', 'Capitol Hill', 'Columbia Heights', 'Dupont Circle', 
    'H Street', 'Navy Yard', 'NoMa', 'Petworth', 'Shaw', 'U Street', 'Union Station'
]

##join the neighborhoods with the or operator
keywords = '|'.join(neighborhoods)

# %%
##filter the data to only include the offense and neighborhood name columns and show the first few rows
with_neighborhoods_filter = (crime_2024.filter(["OFFENSE", "Name"]))
with_neighborhoods_filter.head()
# Out:
#        OFFENSE                  Name
# 0     HOMICIDE  Washington Highlands
# 1     HOMICIDE             Eckington
# 2  THEFT/OTHER           Fort Dupont
# 3  THEFT/OTHER              Trinidad
# 4  THEFT/OTHER             Wakefield

# %%
##filter the data to only show neighborhoods of interest and reset the index
with_neighborhoods_filter_ = with_neighborhoods_filter[with_neighborhoods_filter['Name'].str.contains(keywords, case=False, na=False)]
neighborhoods_cleaned = with_neighborhoods_filter_.reset_index(drop = True)

# %%
##get the shape of the data
neighborhoods_cleaned.shape
# Out:
# (8173, 2)

# %%
##add a count column to the dataframe and show the first few rows
neighborhoods_cleaned["COUNT"] = 1
neighborhoods_cleaned.head()
# Out:
#                OFFENSE              Name  COUNT
# 0          THEFT/OTHER              Shaw      1
# 1          THEFT/OTHER  Columbia Heights      1
# 2          THEFT/OTHER      Capitol Hill      1
# 3          THEFT/OTHER      Adams Morgan      1
# 4  MOTOR VEHICLE THEFT         Anacostia      1

# %%
##add a column with the year 
neighborhoods_cleaned["YEAR"] = 2024

# %%
##Get the total crime by neighborhood by grouping by neighborhood and counting occurences
neighborhoods_cleaned['TotalNeighborhoodCrime'] = neighborhoods_cleaned.groupby('Name')['Name'].transform('count')

# %%
##filter out the anacostia naval station
neighborhoods_cleaned = neighborhoods_cleaned[~neighborhoods_cleaned['Name'].str.contains('Naval', case=False)]

# %%
##get the first few rows
neighborhoods_cleaned.head()
# Out:
#                OFFENSE              Name  YEAR  TotalNeighborhoodCrime
# 0          THEFT/OTHER              Shaw  2024                    1394
# 1          THEFT/OTHER  Columbia Heights  2024                    1545
# 2          THEFT/OTHER      Capitol Hill  2024                    1138
# 3          THEFT/OTHER      Adams Morgan  2024                     686
# 4  MOTOR VEHICLE THEFT         Anacostia  2024                     177

# %%
##Export to a csv
neighborhoods_cleaned.to_csv("../../data/open_data_dc/crime_2024.csv")

# %% [markdown]
# #### Graph crime data in 2024

# %%
##ggplot of crime data by offense in each neighborhood of interest in 2024
crime_2024_plot = (ggplot(data=neighborhoods_cleaned) + 

##bar graph
 geom_bar(

##aesthethics as variable, neighborhood on the x-axis and count on the y with offenses colored in
     aes(x="Name", fill="OFFENSE"), stat="count") +
##minimal theme with labels adjusted to be at a 45 degree angle
    theme_minimal(base_size=8) + 
    theme(axis_text_x=element_text(angle=45, hjust=1)) +


##add labels to both axis, a title and a leged title
labs(x="Neighborhood", y="Crimes Committed", title="Crimes Committed by Neigborhood 2024"))

##show the graph
crime_2024_plot

# %%
##save the graph as a png
ggsave(crime_2024_plot, "../../data/open_data_dc/crime_2024.png")

# %% [markdown]
# #### Functions for merging data and plotting crime for 2019-2023

# %%
##function to merge crime data by year 
def merge_df(crime_csv, year):
    '''
    clean crime data from open data dc for a specific year
    input: csv for that year, year as an int
    output: cleaned csv for that year
    '''
    crime = pd.read_csv(crime_csv)
    with_neighborhoods_filter = crime[crime['Name'].str.contains(keywords, case=False, na=False)]
    with_name_filter = with_neighborhoods_filter.reset_index(drop = True)
    neighborhoods_cleaned = (with_name_filter.filter(["OFFENSE", "Name"]))
    neighborhoods_cleaned['YEAR'] = year
    neighborhoods_cleaned['TotalNeighborhoodCrime'] = neighborhoods_cleaned.groupby('Name')['Name'].transform('count')
    neighborhoods_cleaned = neighborhoods_cleaned[~neighborhoods_cleaned['Name'].str.contains('Naval', case=False)]
    return neighborhoods_cleaned

# %%
##function to graph crime category by neighborhood
def crime_cluster(df, x, fill, year):
    '''
    graph the crime data from open data dc for a specific year
    input: crime dataframe, x-axis column, fill data, year as int
    output: bar graph
    '''
    plot = (ggplot(data=df) + 
    geom_bar(
     aes(x=x, fill=fill), stat="count") +
    theme_minimal(base_size=8) + 
    theme(axis_text_x=element_text(angle=45, hjust=1)) +
    labs(x="Neighborhood", y="Crimes Committed", title= "Crimes Committed by Neigborhood " + year))
    return plot

# %% [markdown]
# #### 2023 Data

# %%
##run merge_df function for 2023 crime data and show the first few rows
crime_2023 = merge_df( "../../data/open_data_dc/Crime_Incidents_in_2023_with_neighborhood.csv", 2023)
crime_2023.head()
# Out:
#                OFFENSE           Name  YEAR  TotalNeighborhoodCrime
# 0          THEFT/OTHER   Capitol Hill  2023                    1241
# 1         THEFT F/AUTO           Shaw  2023                    1740
# 2          THEFT/OTHER   Capitol Hill  2023                    1241
# 3         THEFT F/AUTO  Dupont Circle  2023                     924
# 4  MOTOR VEHICLE THEFT  Dupont Circle  2023                     924

# %%
##get the shape of the data
crime_2023.shape
# Out:
# (10149, 4)

# %%
##Export to a csv
crime_2023.to_csv("../../data/open_data_dc/crime_2023.csv")

# %% [markdown]
# #### 2022 Data

# %%
##run merge_df function for 2022 crime data and show the first few rows
crime_2022 = merge_df("../../data/open_data_dc/Crime_Incidents_in_2022_with_neighborhood.csv", 2022)
crime_2022.head()
# Out:
#         OFFENSE               Name  YEAR  TotalNeighborhoodCrime
# 0      BURGLARY           Petworth  2022                     396
# 1   THEFT/OTHER               Shaw  2022                    1398
# 2  THEFT F/AUTO   Columbia Heights  2022                    1345
# 3   THEFT/OTHER  U Street Corridor  2022                     349
# 4   THEFT/OTHER           Petworth  2022                     396

# %%
##get the shape of the data
crime_2022.shape
# Out:
# (7985, 4)

# %%
##Export to csv
crime_2022.to_csv("../../data/open_data_dc/crime_2022.csv")

# %% [markdown]
# #### 2021 Data

# %%
##run merge_df function for 2021 crime data and show the first few rows
crime_2021 = merge_df("../../data/open_data_dc/Crime_Incidents_in_2021_with_neighborhood.csv", 2021)
crime_2021.head()
# Out:
#                OFFENSE                      Name  YEAR  TotalNeighborhoodCrime
# 0         THEFT F/AUTO             Dupont Circle  2021                     897
# 1  MOTOR VEHICLE THEFT          Columbia Heights  2021                    1457
# 2         THEFT F/AUTO              Capitol Hill  2021                    1297
# 3          THEFT/OTHER              Adams Morgan  2021                     742
# 4          THEFT/OTHER  Sixteenth Street Heights  2021                     783

# %%
##Get the shape of the data
crime_2021.shape
# Out:
# (8658, 4)

# %%
##Export to a csv
crime_2021.to_csv("../../data/open_data_dc/crime_2021.csv")

# %% [markdown]
# #### 2020 Data

# %%
##run merge_df function for 2020 crime data and show the first few rows
crime_2020 = merge_df("../../data/open_data_dc/Crime_Incidents_in_2020_with_neighborhood.csv", 2020)
crime_2020.head()
# Out:
#                OFFENSE           Name  YEAR  TotalNeighborhoodCrime
# 0          THEFT/OTHER  Dupont Circle  2020                     712
# 1         THEFT F/AUTO   Capitol Hill  2020                    1371
# 2          THEFT/OTHER           Shaw  2020                    1038
# 3          THEFT/OTHER   Capitol Hill  2020                    1371
# 4  MOTOR VEHICLE THEFT      Anacostia  2020                     308

# %%
##get the shape of the data
crime_2020.shape
# Out:
# (7553, 4)

# %%
##Export to csv
crime_2020.to_csv("../../data/open_data_dc/crime_2020.csv")

# %% [markdown]
# #### 2019 Data

# %%
##run merge_df function for 2019 crime data and show the first few rows
crime_2019 = merge_df( "../../data/open_data_dc/Crime_Incidents_in_2019_with_neighborhood.csv", 2019)
crime_2019.head()
# Out:
#         OFFENSE          Name  YEAR  TotalNeighborhoodCrime
# 0   THEFT/OTHER          NoMa  2019                     441
# 1  THEFT F/AUTO          Shaw  2019                    1837
# 2  THEFT F/AUTO  Adams Morgan  2019                     635
# 3  THEFT F/AUTO          Shaw  2019                    1837
# 4  THEFT F/AUTO  Adams Morgan  2019                     635

# %%
##Get the shape of the data
crime_2019.shape
# Out:
# (9746, 4)

# %%
##Export to csv
crime_2019.to_csv("../../data/open_data_dc/crime_2019.csv")

# %% [markdown]
# #### Plot 2023 Data

# %%
##Use the crime_cluster function to plot 2023 data
crime_plot_2023 = crime_cluster(crime_2023, "Name", "OFFENSE", '2023')
crime_plot_2023

# %%
##Save the plot as a png
ggsave(crime_plot_2023, "../../data/open_data_dc/crime_2023.png")

# %% [markdown]
# #### Plot 2022 Data

# %%
##Use the crime_cluster function to plot 2022 data
crime_plot_2022 = crime_cluster(crime_2022, "Name", "OFFENSE", '2022')
crime_plot_2022

# %%
##save graph as png
ggsave(crime_plot_2022, "../../data/open_data_dc/crime_2022.png")

# %% [markdown]
# #### Plot 2021 Data

# %%
##Use the crime_cluster function to plot 2021 data
crime_plot_2021 = crime_cluster(crime_2021, "Name", "OFFENSE", '2021')
crime_plot_2021

# %%
##save graph as png
ggsave(crime_plot_2021, "../../data/open_data_dc/crime_2021.png")

# %% [markdown]
# #### Plot 2020 Data

# %%
##Use the crime_cluster function to plot 2020 data
crime_plot_2020 = crime_cluster(crime_2020, "Name", "OFFENSE", '2020')
crime_plot_2020

# %%
##save graph as png
ggsave(crime_plot_2020, "../../data/open_data_dc/crime_2020.png")

# %% [markdown]
# #### Plot 2019 Data

# %%
##Use the crime_cluster function to plot 2019 data
crime_plot_2019 = crime_cluster(crime_2019, "Name", "OFFENSE", '2019')
crime_plot_2019

# %%
##save graph as png
ggsave(crime_plot_2019, "../../data/open_data_dc/crime_2019.png")
