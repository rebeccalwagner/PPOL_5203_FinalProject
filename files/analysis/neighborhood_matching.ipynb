# %% [markdown]
# ### Code to extract neighborhood from crime data

# %%
import pandas as pd
import numpy as np
import string 

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Open Data

# %%
## open first set of csv coded comments
coded_comments_df = pd.read_csv("../../data/reddit/cleaned_sentiment_data.csv")
coded_comments_df.head()
# Out:
#   comment_id submission_id                author  \
# 0    jadntuu       11e8jyj              tehruben
# 1    jadkohn       11e8jyj            Zwicker101
# 2    jagbljj       11e8jyj  UnderwhelmingComment
# 3    jadbu2c       11e8jyj           mr_grission
# 4    jad6inl       11e8jyj            Zwicker101
#
#                                                 body  score  year  month  \
# 0  I used to live at 77H and I both loved and hat...     69  2023      2
# 1  Thats how I felt. Yeah all the people loiterin...     19  2023      2
# 2  The city bent over backwards to attract wal ma...      5  2023      3
# 3  I live in the building and I've been there nea...     11  2023      2
# 4                Honestly? Probably because of crime     12  2023      2
#
#    subreddit  type  sentiment_score
# 0          2     1                3
# 1          2     1                7
# 2          2     1                4
# 3          2     1                7
# 4          2     1                2

# %%
##show only needed columns in df
coded_selected_columns = coded_comments_df[['comment_id', 'submission_id', 'author', 'body', 'sentiment_score']]
coded_selected_columns.head()
# Out:
#   comment_id submission_id                author  \
# 0    jadntuu       11e8jyj              tehruben
# 1    jadkohn       11e8jyj            Zwicker101
# 2    jagbljj       11e8jyj  UnderwhelmingComment
# 3    jadbu2c       11e8jyj           mr_grission
# 4    jad6inl       11e8jyj            Zwicker101
#
#                                                 body  sentiment_score
# 0  I used to live at 77H and I both loved and hat...                3
# 1  Thats how I felt. Yeah all the people loiterin...                7
# 2  The city bent over backwards to attract wal ma...                4
# 3  I live in the building and I've been there nea...                7
# 4                Honestly? Probably because of crime                2

# %% [markdown]
# ### Clean body text

# %%
coded_selected_columns["body"] = [x.lower() for x in coded_selected_columns["body"]] # make lowercase for matching

# %%
# remove punctuation
# coded_selected_columns["body"] = [x.translate(str.maketrans('', '', string.punctuation)) for x in coded_selected_columns["body"]]

# %%
coded_selected_columns["body"] = [x.replace('\n',' ') for x in coded_selected_columns["body"]]

# %%
coded_selected_columns.head()
# Out:
#   comment_id submission_id                author  \
# 0    jadntuu       11e8jyj              tehruben
# 1    jadkohn       11e8jyj            Zwicker101
# 2    jagbljj       11e8jyj  UnderwhelmingComment
# 3    jadbu2c       11e8jyj           mr_grission
# 4    jad6inl       11e8jyj            Zwicker101
#
#                                                 body  sentiment_score
# 0  i used to live at 77h and i both loved and hat...                3
# 1  thats how i felt. yeah all the people loiterin...                7
# 2  the city bent over backwards to attract wal ma...                4
# 3  i live in the building and i've been there nea...                7
# 4                honestly? probably because of crime                2

# %%
# all identifying neighborhoods/region words
neighborhoods = [
    'Adams Morgan', 'American University Park', 'Anacostia', 'Barnaby Woods', 
    'Capitol Hill', 'Columbia Heights', 'Cleveland Park', 'Dupont', 
    'Foggy Bottom', 'Friendship Heights', 'Georgetown', 'Glover Park', 
    'H Street', 'Logan Circle', 'Mount Pleasant', 'Navy Yard', 
    'NoMa', 'Petworth', 'Shaw', 'Southwest Waterfront', 'Takoma', 
    'Tenleytown', 'The Palisades', 'U Street', 'West End', 'Woodley Park']

abbreviations = ['EOTR','Cheights', ' CH ', 'Admo', 'Downtown', 'central', 
                 ' SW ', ' SE ', ' NE ', 'north east', 'south east', 'north west']

# combine and make lowercase for matching to tokens
search_terms = neighborhoods + abbreviations
search_terms = [x.lower() for x in search_terms]

# %%
##function to apply to the body column
def get_neighborhoods(text):
    matches = [term for term in search_terms if term in text]
    return ', '.join(matches) if matches else None

coded_selected_columns['neighborhoods_mentioned'] = coded_selected_columns['body'].apply(get_neighborhoods)

# %%
coded_selected_columns
# Out:
#      comment_id submission_id                author  \
# 0       jadntuu       11e8jyj              tehruben
# 1       jadkohn       11e8jyj            Zwicker101
# 2       jagbljj       11e8jyj  UnderwhelmingComment
# 3       jadbu2c       11e8jyj           mr_grission
# 4       jad6inl       11e8jyj            Zwicker101
# ...         ...           ...                   ...
# 6440    eyh4z5x        cwurzh             jbrofford
# 6441    eyjy72n        cwurzh       zetuslapetus311
# 6442    eyhlyi5        cwurzh        millennial_bot
# 6443    eyfn4hy        cwurzh                   NaN
# 6444    eyh0r73        cwurzh       NoNoNoNoNOTinks
#
#                                                    body  sentiment_score  \
# 0     i used to live at 77h and i both loved and hat...                3
# 1     thats how i felt. yeah all the people loiterin...                7
# 2     the city bent over backwards to attract wal ma...                4
# 3     i live in the building and i've been there nea...                7
# 4                   honestly? probably because of crime                2
# ...                                                 ...              ...
# 6440  did the op even call 911? neighbors need to wa...                4
# 6441  dc needs a more moderate mayor. who cares abou...                3
# 6442  the problem isn't entirely mpd, the courts are...                2
# 6443  what would you like mpd to do about the pcp, e...                3
# 6444  "i'm sick of mpd not doing anything about the ...                3
#
#      neighborhoods_mentioned
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 6440                    None
# 6441                    None
# 6442                    None
# 6443                    None
# 6444                    None
#
# [6445 rows x 6 columns]

# %%
yes_neighborhoods = coded_selected_columns[coded_selected_columns["neighborhoods_mentioned"].apply(lambda x: x is not None)]
yes_neighborhoods.head()
# Out:
#    comment_id submission_id               author  \
# 7     jadkvdl       11e8jyj          digitall565
# 21    gzixvn7        nljeif  frenchvanilafantasy
# 23    gzixppj        nljeif                  NaN
# 24    gzjrh9w        nljeif       lonliestnumber
# 28    gzjfj9w        nljeif              DJCWick
#
#                                                  body  sentiment_score  \
# 7   yep. i've seen more go down at stores in sw an...                4
# 21  my office is located in noma and we received a...                3
# 23  i mean, noma has been like this for a while. a...                2
# 24  i recently moved to noma this year so i wouldn...                3
# 28  been in noma for 3 years, and it's definitely ...                3
#
#    neighborhoods_mentioned
# 7          navy yard,  sw
# 21                    noma
# 23                    noma
# 24                    noma
# 28                    noma

# %%
no_neighborhoods = coded_selected_columns[[isinstance(x, type(None)) for x in coded_selected_columns["neighborhoods_mentioned"]]]
no_neighborhoods.head()
# Out:
#   comment_id submission_id                author  \
# 0    jadntuu       11e8jyj              tehruben
# 1    jadkohn       11e8jyj            Zwicker101
# 2    jagbljj       11e8jyj  UnderwhelmingComment
# 3    jadbu2c       11e8jyj           mr_grission
# 4    jad6inl       11e8jyj            Zwicker101
#
#                                                 body  sentiment_score  \
# 0  i used to live at 77h and i both loved and hat...                3
# 1  thats how i felt. yeah all the people loiterin...                7
# 2  the city bent over backwards to attract wal ma...                4
# 3  i live in the building and i've been there nea...                7
# 4                honestly? probably because of crime                2
#
#   neighborhoods_mentioned
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None

# %%
no_neighborhoods.shape
# Out:
# (5005, 6)

# %% [markdown]
# ### Match None Comments with Threads

# %%
threads_all = pd.read_csv("../../data/reddit/original_scraped_data/threads_ALL_12_6.csv")
threads_all.head()
# Out:
#    Unnamed: 0 submission_id  \
# 0           0        y57cbw
# 1           2        32cqd6
# 2           4       1h3ldb4
# 3           5       1gs6shr
# 4           6       1fbfdzi
#
#                                                title  \
# 0     Best quiet, safe but lively neighborhood in DC
# 1  Recommendations on safe neighborhoods for a yo...
# 2  1 Month of Free Rent in 770 SQFT. High Rise Ap...
# 3                    Spacious studio in Woodley park
# 4              ISO 12 month sublet starting 11-22-24
#
#                                                 text  year  month  subreddit  \
# 0  I am in my late 30s and haven't lived in DC si...  2022     10          0
# 1  I'm moving to DC from the South in a few weeks...  2015      4          0
# 2  Apartment Takeover Opportunity: Market House i...  2024     11          0
# 3  Spacious studio available for lease takeover s...  2024     11          0
# 4  Hi there I recently relocated for work ( in Ro...  2024      9          0
#
#    type
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
merge_threads = no_neighborhoods.merge(threads_all[["submission_id","text","title"]], on="submission_id", how="left")
merge_threads.head()
# Out:
#   comment_id submission_id                author  \
# 0    jadntuu       11e8jyj              tehruben
# 1    jadkohn       11e8jyj            Zwicker101
# 2    jagbljj       11e8jyj  UnderwhelmingComment
# 3    jadbu2c       11e8jyj           mr_grission
# 4    jad6inl       11e8jyj            Zwicker101
#
#                                                 body  sentiment_score  \
# 0  i used to live at 77h and i both loved and hat...                3
# 1  thats how i felt. yeah all the people loiterin...                7
# 2  the city bent over backwards to attract wal ma...                4
# 3  i live in the building and i've been there nea...                7
# 4                honestly? probably because of crime                2
#
#   neighborhoods_mentioned                                               text  \
# 0                    None  New sign indicates that Walmart on H Street is...
# 1                    None  New sign indicates that Walmart on H Street is...
# 2                    None  New sign indicates that Walmart on H Street is...
# 3                    None  New sign indicates that Walmart on H Street is...
# 4                    None  New sign indicates that Walmart on H Street is...
#
#                                        title
# 0  Walmart on H Street Closing on March 31st
# 1  Walmart on H Street Closing on March 31st
# 2  Walmart on H Street Closing on March 31st
# 3  Walmart on H Street Closing on March 31st
# 4  Walmart on H Street Closing on March 31st

# %% [markdown]
# ### Clean threads & match with neighborhoods

# %%
merge_threads["title_text"] = merge_threads["title"] + " " + merge_threads["text"] # combine title and submission body

# %%
merge_threads["title_text"] = [str(x).lower() for x in merge_threads["title_text"]] # make lowercase for matching

# %%
merge_threads["title_text"] = [x.replace('\n',' ') for x in merge_threads["title_text"]] # remove newline characters

# %%
merge_threads.head()
# Out:
#   comment_id submission_id                author  \
# 0    jadntuu       11e8jyj              tehruben
# 1    jadkohn       11e8jyj            Zwicker101
# 2    jagbljj       11e8jyj  UnderwhelmingComment
# 3    jadbu2c       11e8jyj           mr_grission
# 4    jad6inl       11e8jyj            Zwicker101
#
#                                                 body  sentiment_score  \
# 0  i used to live at 77h and i both loved and hat...                3
# 1  thats how i felt. yeah all the people loiterin...                7
# 2  the city bent over backwards to attract wal ma...                4
# 3  i live in the building and i've been there nea...                7
# 4                honestly? probably because of crime                2
#
#   neighborhoods_mentioned                                               text  \
# 0                    None  New sign indicates that Walmart on H Street is...
# 1                    None  New sign indicates that Walmart on H Street is...
# 2                    None  New sign indicates that Walmart on H Street is...
# 3                    None  New sign indicates that Walmart on H Street is...
# 4                    None  New sign indicates that Walmart on H Street is...
#
#                                        title  \
# 0  Walmart on H Street Closing on March 31st
# 1  Walmart on H Street Closing on March 31st
# 2  Walmart on H Street Closing on March 31st
# 3  Walmart on H Street Closing on March 31st
# 4  Walmart on H Street Closing on March 31st
#
#                                           title_text
# 0  walmart on h street closing on march 31st new ...
# 1  walmart on h street closing on march 31st new ...
# 2  walmart on h street closing on march 31st new ...
# 3  walmart on h street closing on march 31st new ...
# 4  walmart on h street closing on march 31st new ...

# %%
merge_threads['neighborhoods_mentioned_submission'] = merge_threads['title_text'].apply(get_neighborhoods)

# %%
merge_threads
# Out:
#      comment_id submission_id                author  \
# 0       jadntuu       11e8jyj              tehruben
# 1       jadkohn       11e8jyj            Zwicker101
# 2       jagbljj       11e8jyj  UnderwhelmingComment
# 3       jadbu2c       11e8jyj           mr_grission
# 4       jad6inl       11e8jyj            Zwicker101
# ...         ...           ...                   ...
# 5000    eyh4z5x        cwurzh             jbrofford
# 5001    eyjy72n        cwurzh       zetuslapetus311
# 5002    eyhlyi5        cwurzh        millennial_bot
# 5003    eyfn4hy        cwurzh                   NaN
# 5004    eyh0r73        cwurzh       NoNoNoNoNOTinks
#
#                                                    body  sentiment_score  \
# 0     i used to live at 77h and i both loved and hat...                3
# 1     thats how i felt. yeah all the people loiterin...                7
# 2     the city bent over backwards to attract wal ma...                4
# 3     i live in the building and i've been there nea...                7
# 4                   honestly? probably because of crime                2
# ...                                                 ...              ...
# 5000  did the op even call 911? neighbors need to wa...                4
# 5001  dc needs a more moderate mayor. who cares abou...                3
# 5002  the problem isn't entirely mpd, the courts are...                2
# 5003  what would you like mpd to do about the pcp, e...                3
# 5004  "i'm sick of mpd not doing anything about the ...                3
#
#      neighborhoods_mentioned  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 5000                    None
# 5001                    None
# 5002                    None
# 5003                    None
# 5004                    None
#
#                                                    text  \
# 0     New sign indicates that Walmart on H Street is...
# 1     New sign indicates that Walmart on H Street is...
# 2     New sign indicates that Walmart on H Street is...
# 3     New sign indicates that Walmart on H Street is...
# 4     New sign indicates that Walmart on H Street is...
# ...                                                 ...
# 5000  I witnessed the stabbing on Irving Street last...
# 5001  I witnessed the stabbing on Irving Street last...
# 5002  I witnessed the stabbing on Irving Street last...
# 5003  I witnessed the stabbing on Irving Street last...
# 5004  I witnessed the stabbing on Irving Street last...
#
#                                           title  \
# 0     Walmart on H Street Closing on March 31st
# 1     Walmart on H Street Closing on March 31st
# 2     Walmart on H Street Closing on March 31st
# 3     Walmart on H Street Closing on March 31st
# 4     Walmart on H Street Closing on March 31st
# ...                                         ...
# 5000  I witnessed the stabbing on Irving Street
# 5001  I witnessed the stabbing on Irving Street
# 5002  I witnessed the stabbing on Irving Street
# 5003  I witnessed the stabbing on Irving Street
# 5004  I witnessed the stabbing on Irving Street
#
#                                              title_text  \
# 0     walmart on h street closing on march 31st new ...
# 1     walmart on h street closing on march 31st new ...
# 2     walmart on h street closing on march 31st new ...
# 3     walmart on h street closing on march 31st new ...
# 4     walmart on h street closing on march 31st new ...
# ...                                                 ...
# 5000  i witnessed the stabbing on irving street i wi...
# 5001  i witnessed the stabbing on irving street i wi...
# 5002  i witnessed the stabbing on irving street i wi...
# 5003  i witnessed the stabbing on irving street i wi...
# 5004  i witnessed the stabbing on irving street i wi...
#
#      neighborhoods_mentioned_submission
# 0                              h street
# 1                              h street
# 2                              h street
# 3                              h street
# 4                              h street
# ...                                 ...
# 5000                               None
# 5001                               None
# 5002                               None
# 5003                               None
# 5004                               None
#
# [5005 rows x 10 columns]

# %%
merge_threads_neighborhoods = merge_threads[merge_threads["neighborhoods_mentioned_submission"].apply(lambda x: x is not None)]
merge_threads_neighborhoods.head()
# Out:
#   comment_id submission_id                author  \
# 0    jadntuu       11e8jyj              tehruben
# 1    jadkohn       11e8jyj            Zwicker101
# 2    jagbljj       11e8jyj  UnderwhelmingComment
# 3    jadbu2c       11e8jyj           mr_grission
# 4    jad6inl       11e8jyj            Zwicker101
#
#                                                 body  sentiment_score  \
# 0  i used to live at 77h and i both loved and hat...                3
# 1  thats how i felt. yeah all the people loiterin...                7
# 2  the city bent over backwards to attract wal ma...                4
# 3  i live in the building and i've been there nea...                7
# 4                honestly? probably because of crime                2
#
#   neighborhoods_mentioned                                               text  \
# 0                    None  New sign indicates that Walmart on H Street is...
# 1                    None  New sign indicates that Walmart on H Street is...
# 2                    None  New sign indicates that Walmart on H Street is...
# 3                    None  New sign indicates that Walmart on H Street is...
# 4                    None  New sign indicates that Walmart on H Street is...
#
#                                        title  \
# 0  Walmart on H Street Closing on March 31st
# 1  Walmart on H Street Closing on March 31st
# 2  Walmart on H Street Closing on March 31st
# 3  Walmart on H Street Closing on March 31st
# 4  Walmart on H Street Closing on March 31st
#
#                                           title_text  \
# 0  walmart on h street closing on march 31st new ...
# 1  walmart on h street closing on march 31st new ...
# 2  walmart on h street closing on march 31st new ...
# 3  walmart on h street closing on march 31st new ...
# 4  walmart on h street closing on march 31st new ...
#
#   neighborhoods_mentioned_submission
# 0                           h street
# 1                           h street
# 2                           h street
# 3                           h street
# 4                           h street

# %% [markdown]
# ### Join thread neighborhood data with comment neighborhood data

# %%
yes_neighborhoods
# Out:
#      comment_id submission_id               author  \
# 7       jadkvdl       11e8jyj          digitall565
# 21      gzixvn7        nljeif  frenchvanilafantasy
# 23      gzixppj        nljeif                  NaN
# 24      gzjrh9w        nljeif       lonliestnumber
# 28      gzjfj9w        nljeif              DJCWick
# ...         ...           ...                  ...
# 6416    js5fn86       150nxj6   ThatDudeFromPlaces
# 6424    c5tvhmv         ya0e5              DCBacon
# 6425    c5tua0p         ya0e5          rasputin777
# 6427    c5tx9tg         ya0e5       JohnnyMcDoodle
# 6437    eyjddqc        cwurzh                  NaN
#
#                                                    body  sentiment_score  \
# 7     yep. i've seen more go down at stores in sw an...                4
# 21    my office is located in noma and we received a...                3
# 23    i mean, noma has been like this for a while. a...                2
# 24    i recently moved to noma this year so i wouldn...                3
# 28    been in noma for 3 years, and it's definitely ...                3
# ...                                                 ...              ...
# 6416  pre 2019 my buddies and i would all walk home ...                3
# 6424  so the "scary" places that you never go to wil...                6
# 6425  there don't seem to be any from the actually b...               10
# 6427  safer in anacostia? i'm calling bullshit. crim...                2
# 6437  for those who argue in favor of reduced senten...                2
#
#      neighborhoods_mentioned
# 7            navy yard,  sw
# 21                      noma
# 23                      noma
# 24                      noma
# 28                      noma
# ...                      ...
# 6416      woodley park, admo
# 6424   anacostia, georgetown
# 6425               anacostia
# 6427               anacostia
# 6437                    admo
#
# [1440 rows x 6 columns]

# %%
all_neighborhood_data = pd.concat([yes_neighborhoods,merge_threads_neighborhoods])

# %%
all_neighborhood_data.columns
# Out:
# Index(['comment_id', 'submission_id', 'author', 'body', 'sentiment_score',
#        'neighborhoods_mentioned', 'text', 'title', 'title_text',
#        'neighborhoods_mentioned_submission'],
#       dtype='object')

# %%
all_neighborhood_data = all_neighborhood_data.rename(columns={"body":"comment_text","title_text":"thread_text"})

# %%
all_neighborhood_data = all_neighborhood_data.drop(["text","title"],axis=1)

# %%
all_neighborhood_data
# Out:
#      comment_id submission_id               author  \
# 7       jadkvdl       11e8jyj          digitall565
# 21      gzixvn7        nljeif  frenchvanilafantasy
# 23      gzixppj        nljeif                  NaN
# 24      gzjrh9w        nljeif       lonliestnumber
# 28      gzjfj9w        nljeif              DJCWick
# ...         ...           ...                  ...
# 4982    js5ar6m       150nxj6             iidesune
# 4983    js57acg       150nxj6          Freezerburn
# 4984    js6f38b       150nxj6       Deep_Stick8786
# 4985    js69z1j       150nxj6                  NaN
# 4986    js6m3l1       150nxj6              Tcr8888
#
#                                            comment_text  sentiment_score  \
# 7     yep. i've seen more go down at stores in sw an...                4
# 21    my office is located in noma and we received a...                3
# 23    i mean, noma has been like this for a while. a...                2
# 24    i recently moved to noma this year so i wouldn...                3
# 28    been in noma for 3 years, and it's definitely ...                3
# ...                                                 ...              ...
# 4982  i'd say dc is definitely carrying more than it...                3
# 4983  that implies that i would break the law and ca...                3
# 4984  until you wear a canada goose in winter. but y...                4
# 4985  for years the draconian gun laws favored crimi...                2
# 4986  you’d be very foolish to go anywhere in dc wit...                2
#
#      neighborhoods_mentioned  \
# 7            navy yard,  sw
# 21                      noma
# 23                      noma
# 24                      noma
# 28                      noma
# ...                      ...
# 4982                    None
# 4983                    None
# 4984                    None
# 4985                    None
# 4986                    None
#
#                                             thread_text  \
# 7                                                   NaN
# 21                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 28                                                  NaN
# ...                                                 ...
# 4982  multiple robberies in admo (popville) be safe ...
# 4983  multiple robberies in admo (popville) be safe ...
# 4984  multiple robberies in admo (popville) be safe ...
# 4985  multiple robberies in admo (popville) be safe ...
# 4986  multiple robberies in admo (popville) be safe ...
#
#      neighborhoods_mentioned_submission
# 7                                   NaN
# 21                                  NaN
# 23                                  NaN
# 24                                  NaN
# 28                                  NaN
# ...                                 ...
# 4982                               admo
# 4983                               admo
# 4984                               admo
# 4985                               admo
# 4986                               admo
#
# [4067 rows x 8 columns]

# %%
all_neighborhood_data["neighborhoods_mentioned"] = all_neighborhood_data["neighborhoods_mentioned"].fillna(all_neighborhood_data["neighborhoods_mentioned_submission"])

# %%
all_neighborhood_data.drop(["author","neighborhoods_mentioned_submission"],axis=1)
# Out:
#      comment_id submission_id  \
# 7       jadkvdl       11e8jyj
# 21      gzixvn7        nljeif
# 23      gzixppj        nljeif
# 24      gzjrh9w        nljeif
# 28      gzjfj9w        nljeif
# ...         ...           ...
# 4982    js5ar6m       150nxj6
# 4983    js57acg       150nxj6
# 4984    js6f38b       150nxj6
# 4985    js69z1j       150nxj6
# 4986    js6m3l1       150nxj6
#
#                                            comment_text  sentiment_score  \
# 7     yep. i've seen more go down at stores in sw an...                4
# 21    my office is located in noma and we received a...                3
# 23    i mean, noma has been like this for a while. a...                2
# 24    i recently moved to noma this year so i wouldn...                3
# 28    been in noma for 3 years, and it's definitely ...                3
# ...                                                 ...              ...
# 4982  i'd say dc is definitely carrying more than it...                3
# 4983  that implies that i would break the law and ca...                3
# 4984  until you wear a canada goose in winter. but y...                4
# 4985  for years the draconian gun laws favored crimi...                2
# 4986  you’d be very foolish to go anywhere in dc wit...                2
#
#      neighborhoods_mentioned  \
# 7            navy yard,  sw
# 21                      noma
# 23                      noma
# 24                      noma
# 28                      noma
# ...                      ...
# 4982                    admo
# 4983                    admo
# 4984                    admo
# 4985                    admo
# 4986                    admo
#
#                                             thread_text
# 7                                                   NaN
# 21                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 28                                                  NaN
# ...                                                 ...
# 4982  multiple robberies in admo (popville) be safe ...
# 4983  multiple robberies in admo (popville) be safe ...
# 4984  multiple robberies in admo (popville) be safe ...
# 4985  multiple robberies in admo (popville) be safe ...
# 4986  multiple robberies in admo (popville) be safe ...
#
# [4067 rows x 6 columns]

# %%
all_neighborhood_data = all_neighborhood_data[['comment_id', 'submission_id', 'comment_text', 'thread_text', 'neighborhoods_mentioned', 'sentiment_score']]

# %%
all_neighborhood_data.to_csv("../../data/reddit/gpt_sentiment_with_neighborhoods.csv",index=False)
