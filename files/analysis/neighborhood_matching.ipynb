# %% [markdown]
# ### Code to extract neighborhood from crime data

# %%
import pandas as pd
import numpy as np
import string 

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Open Data

# %%
## open first set of csv coded comments
coded_comments_df = pd.read_csv("../data/reddit/cleaned_sentiment_data.csv")
coded_comments_df.head()
# Out:
#   comment_id submission_id            author  \
# 0    ita0jq1        y57cbw      samthehaggis
# 1    i9cnmct        utr8aw         dans_cafe
# 2    i9csov5        utr8aw  Ok_Priority_1534
# 3    i9czvva        utr8aw         dans_cafe
# 4    cqarv2e        32cqd6          AUBlazin
#
#                                                 body  score  year  month  \
# 0  Agreed to Cleveland Park and Woodley Park. The...      1  2022     10
# 1  Generally speaking, robberies and muggings are...      1  2022      5
# 2  Downtown/Central DC.\n\nAs I'm looking at diff...      1  2022      5
# 3  of course there are.  And probably, it's over-...      1  2022      5
# 4  Haha well you have decided to live in the sket...      1  2015      4
#
#    subreddit  type  sentiment_score
# 0          0     1                8
# 1          0     1                4
# 2          0     1                7
# 3          0     1                7
# 4          0     1                6

# %%
##show only needed columns in df
coded_selected_columns = coded_comments_df[['comment_id', 'submission_id', 'author', 'body', 'sentiment_score']]
coded_selected_columns.head()
# Out:
#   comment_id submission_id            author  \
# 0    ita0jq1        y57cbw      samthehaggis
# 1    i9cnmct        utr8aw         dans_cafe
# 2    i9csov5        utr8aw  Ok_Priority_1534
# 3    i9czvva        utr8aw         dans_cafe
# 4    cqarv2e        32cqd6          AUBlazin
#
#                                                 body  sentiment_score
# 0  Agreed to Cleveland Park and Woodley Park. The...                8
# 1  Generally speaking, robberies and muggings are...                4
# 2  Downtown/Central DC.\n\nAs I'm looking at diff...                7
# 3  of course there are.  And probably, it's over-...                7
# 4  Haha well you have decided to live in the sket...                6

# %% [markdown]
# ### Clean body text

# %%
coded_selected_columns["body"] = [x.lower() for x in coded_selected_columns["body"]] # make lowercase for matching

# %%
# remove punctuation
# coded_selected_columns["body"] = [x.translate(str.maketrans('', '', string.punctuation)) for x in coded_selected_columns["body"]]

# %%
coded_selected_columns["body"] = [x.replace('\n',' ') for x in coded_selected_columns["body"]]

# %%
coded_selected_columns.head()
# Out:
#   comment_id submission_id            author  \
# 0    ita0jq1        y57cbw      samthehaggis
# 1    i9cnmct        utr8aw         dans_cafe
# 2    i9csov5        utr8aw  Ok_Priority_1534
# 3    i9czvva        utr8aw         dans_cafe
# 4    cqarv2e        32cqd6          AUBlazin
#
#                                                 body  sentiment_score
# 0  agreed to cleveland park and woodley park. the...                8
# 1  generally speaking, robberies and muggings are...                4
# 2  downtown/central dc.  as i'm looking at differ...                7
# 3  of course there are.  and probably, it's over-...                7
# 4  haha well you have decided to live in the sket...                6

# %%
# all identifying neighborhoods/region words
neighborhoods = [
    'Adams Morgan', 'American University Park', 'Anacostia', 'Barnaby Woods', 
    'Capitol Hill', 'Columbia Heights', 'Cleveland Park', 'Dupont', 
    'Foggy Bottom', 'Friendship Heights', 'Georgetown', 'Glover Park', 
    'H Street', 'Logan Circle', 'Mount Pleasant', 'Navy Yard', 
    'NoMa', 'Petworth', 'Shaw', 'Southwest Waterfront', 'Takoma', 
    'Tenleytown', 'The Palisades', 'U Street', 'West End', 'Woodley Park']

abbreviations = ['EOTR','Cheights', ' CH ', 'Admo', 'Downtown', 'central', 
                 'SW', 'SE', 'NE', 'north east', 'south east', 'north west']

# combine and make lowercase for matching to tokens
search_terms = neighborhoods + abbreviations
search_terms = [x.lower() for x in search_terms]

# %%
##function to apply to the body column
def get_neighborhoods(text):
    matches = [term for term in search_terms if term in text]
    return ', '.join(matches) if matches else None

coded_selected_columns['neighborhoods_mentioned'] = coded_selected_columns['body'].apply(get_neighborhoods)

# %%
coded_selected_columns.head(15)
# Out:
#    comment_id submission_id               author  \
# 0     ita0jq1        y57cbw         samthehaggis
# 1     i9cnmct        utr8aw            dans_cafe
# 2     i9csov5        utr8aw     Ok_Priority_1534
# 3     i9czvva        utr8aw            dans_cafe
# 4     cqarv2e        32cqd6             AUBlazin
# 5     cg6zt92        20t3z6                  NaN
# 6     cg7mdys        20t3z6             AUBlazin
# 7     k65n8fq       17ed6rg               Brinzy
# 8     k65oqmg       17ed6rg             Snowbold
# 9     k6rdhmy       17ed6rg              mm10102
# 10    jaoobo5       11burox  Brave_Tangerine1240
# 11    ja0rrp7       11burox        caseadilla111
# 12    io7q6fe        xciciq        yasssssplease
# 13    jlfzfln       13qokxh   myloversacarnivore
# 14    ibpknp9        v6dd5a      crystalsnow2796
#
#                                                  body  sentiment_score  \
# 0   agreed to cleveland park and woodley park. the...                8
# 1   generally speaking, robberies and muggings are...                4
# 2   downtown/central dc.  as i'm looking at differ...                7
# 3   of course there are.  and probably, it's over-...                7
# 4   haha well you have decided to live in the sket...                6
# 5   unfortunately mpd is notorious for underreport...                3
# 6   i completely understand and believe what you a...                5
# 7   i am not a super nature-y person myself, so ym...                7
# 8   i had this same issue while finding a place. i...                7
# 9   woodley park and cleveland park have one beds ...                7
# 10  hi there! this is a little bit above the budge...                8
# 11  would you mind sharing which apartment? i live...                5
# 12  if you’re looking to move into the district, i...                7
# 13  neighborhood safety is a separate concern from...                8
# 14  thank you so much, based on availability and c...                5
#
#                  neighborhoods_mentioned
# 0           cleveland park, woodley park
# 1                   h street, takoma, ne
# 2              downtown, central, se, ne
# 3                             sw, se, ne
# 4             capitol hill, noma, se, ne
# 5                                 se, ne
# 6                                   None
# 7                             sw, se, ne
# 8                                   None
# 9   cleveland park, woodley park, se, ne
# 10                                    se
# 11                              noma, se
# 12                  capitol hill, se, ne
# 13                                se, ne
# 14                                    se

# %% [markdown]
# ### Look at none comments

# %%
coded_selected_columns[[isinstance(x, type(None)) for x in coded_selected_columns["neighborhoods_mentioned"]]]
# Out:
#      comment_id submission_id              author  \
# 6       cg7mdys        20t3z6            AUBlazin
# 8       k65oqmg       17ed6rg            Snowbold
# 40      lzn9uwz       1h2wunn    Kind_Mixture1649
# 43      lzsvxnw       1h2wunn  Adorable-Golf-2113
# 50      m01a4b0       1h2wunn   Beginning-Gur4706
# ...         ...           ...                 ...
# 5334    ie9skxh        vmknzh      Failninjaninja
# 5341    jkwfgsj       13mjnq2             EC_dwtn
# 5356    eyh30ml        cwurzh      geauxing4broke
# 5358    cbd8oyx        1jbs1a          Baloncesto
# 5360    jbodfxm       11nf3e0      Super_lobbyist
#
#                                                    body  sentiment_score  \
# 6     i completely understand and believe what you a...                5
# 8     i had this same issue while finding a place. i...                7
# 40             you couldn’t pay me to hang out on u st.                3
# 43    the reason is the parents aren't raising their...                4
# 50    the police could stop it. it would be violent ...                3
# ...                                                 ...              ...
# 5334  ending soft on crime policies would be a terri...                3
# 5341  3d has more carjackings than 7d so far this ye...                4
# 5356  i had a similar experience my first week in dc...                3
# 5358  yeah, that area is okay. you'll be right acros...                6
# 5360  safe versus unsafe isn't exactly a black-and-w...                6
#
#      neighborhoods_mentioned
# 6                       None
# 8                       None
# 40                      None
# 43                      None
# 50                      None
# ...                      ...
# 5334                    None
# 5341                    None
# 5356                    None
# 5358                    None
# 5360                    None
#
# [755 rows x 6 columns]

# %%
### We can try to match them with the thread body - might not be necessary though
